# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from statsmodels.tsa.stattools import adfuller
from pmdarima.arima import auto_arima

import patsy                           # provides a syntax for specifying models  
import statsmodels.api as sm           # provides statistical models like ols, gmm, anova, etc...; 
                                       # for Cross-sectional models and methods.
import statsmodels.formula.api as smf  # provides a way to directly spec models from formulas

# %%
df = pd.read_csv("Walworth_County_ACS_Data_2014-2020_Group_1.csv")

# %%
df.head()
# Out:
#          Municipality  Year  No health insurance coverage  Less than $10,000  \
# 0     Bloomfield town  2020                          0.13               0.08
# 1  Bloomfield village  2020                          0.07               0.03
# 2     Burlington city  2020                          0.00               0.00
# 3         Darien town  2020                          0.12               0.02
# 4      Darien village  2020                          0.07               0.02
#
#    $10,000 to $14,999  $15,000 to $24,999  Unemployed  No vehicles available  \
# 0                0.03                0.12        0.04                   0.01
# 1                0.07                0.09        0.04                   0.02
# 2                0.00                0.00        0.00                   0.00
# 3                0.02                0.13        0.01                   0.02
# 4                0.02                0.04        0.05                   0.00
#
#    Less than 9th grade  9th to 12th grade, no diploma  Child  Foreign born  \
# 0                 0.09                           0.06   0.32          0.11
# 1                 0.01                           0.14   0.39          0.03
# 2                 0.00                           0.00   0.00          0.00
# 3                 0.05                           0.10   0.35          0.08
# 4                 0.00                           0.07   0.31          0.05
#
#    Speak English less than "very well"  \
# 0                                 0.07
# 1                                 0.02
# 2                                 0.00
# 3                                 0.10
# 4                                 0.02
#
#    With a broadband Internet subscription  Average family size  \
# 0                                    0.80                 3.08
# 1                                    0.81                 3.18
# 2                                    0.00                  NaN
# 3                                    0.85                 3.28
# 4                                    0.85                 3.06
#
#    Median age (years)
# 0                34.9
# 1                35.9
# 2                 NaN
# 3                43.7
# 4                36.7

# %%
df.columns
# Out:
# Index(['Municipality', 'Year', 'No health insurance coverage',
#        'Less than $10,000', '$10,000 to $14,999', '$15,000 to $24,999',
#        'Unemployed', 'No vehicles available', 'Less than 9th grade',
#        '9th to 12th grade, no diploma', 'Child', 'Foreign born',
#        'Speak English less than "very well"',
#        'With a broadband Internet subscription', 'Average family size',
#        'Median age (years)'],
#       dtype='object')

# %%
df1=df.fillna(0)

# %%
df1['Less than $25,000'] = df1['Less than $10,000'] + df1['$10,000 to $14,999'] + df1['$15,000 to $24,999']
df1['Less than 12th grade'] = df1['Less than 9th grade'] + df1['9th to 12th grade, no diploma']
df1['Without a broadband Internet subscription'] = 1-df1['With a broadband Internet subscription']

# %%
df1.head()
# Out:
#          Municipality  Year  No health insurance coverage  Less than $10,000  \
# 0     Bloomfield town  2020                          0.13               0.08
# 1  Bloomfield village  2020                          0.07               0.03
# 2     Burlington city  2020                          0.00               0.00
# 3         Darien town  2020                          0.12               0.02
# 4      Darien village  2020                          0.07               0.02
#
#    $10,000 to $14,999  $15,000 to $24,999  Unemployed  No vehicles available  \
# 0                0.03                0.12        0.04                   0.01
# 1                0.07                0.09        0.04                   0.02
# 2                0.00                0.00        0.00                   0.00
# 3                0.02                0.13        0.01                   0.02
# 4                0.02                0.04        0.05                   0.00
#
#    Less than 9th grade  9th to 12th grade, no diploma  Child  Foreign born  \
# 0                 0.09                           0.06   0.32          0.11
# 1                 0.01                           0.14   0.39          0.03
# 2                 0.00                           0.00   0.00          0.00
# 3                 0.05                           0.10   0.35          0.08
# 4                 0.00                           0.07   0.31          0.05
#
#    Speak English less than "very well"  \
# 0                                 0.07
# 1                                 0.02
# 2                                 0.00
# 3                                 0.10
# 4                                 0.02
#
#    With a broadband Internet subscription  Average family size  \
# 0                                    0.80                 3.08
# 1                                    0.81                 3.18
# 2                                    0.00                 0.00
# 3                                    0.85                 3.28
# 4                                    0.85                 3.06
#
#    Median age (years)  Less than $25,000  Less than 12th grade  \
# 0                34.9               0.23                  0.15
# 1                35.9               0.19                  0.15
# 2                 0.0               0.00                  0.00
# 3                43.7               0.17                  0.15
# 4                36.7               0.08                  0.07
#
#    Without a broadband Internet subscription
# 0                                       0.20
# 1                                       0.19
# 2                                       1.00
# 3                                       0.15
# 4                                       0.15

# %%
df2 = df1.drop(['Less than $10,000','$10,000 to $14,999', '$15,000 to $24,999','Less than 9th grade',
                '9th to 12th grade, no diploma','Average family size',
               'With a broadband Internet subscription'], axis=1)

# %%
df2.columns
# Out:
# Index(['Municipality', 'Year', 'No health insurance coverage', 'Unemployed',
#        'No vehicles available', 'Child', 'Foreign born',
#        'Speak English less than "very well"', 'Median age (years)',
#        'Less than $25,000', 'Less than 12th grade',
#        'Without a broadband Internet subscription'],
#       dtype='object')

# %%
correlation = df2.corr()

# %%
correlation.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_63fee_row0_col0, #T_63fee_row1_col1, #T_63fee_row2_col2, #T_63fee_row3_col3, #T_63fee_row4_col4, #T_63fee_row5_col5, #T_63fee_row6_col6, #T_63fee_row7_col7, #T_63fee_row8_col8, #T_63fee_row9_col9, #T_63fee_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_63fee_row0_col1, #T_63fee_row0_col2, #T_63fee_row0_col3, #T_63fee_row0_col8, #T_63fee_row0_col9, #T_63fee_row0_col10, #T_63fee_row7_col6, #T_63fee_row10_col0, #T_63fee_row10_col4, #T_63fee_row10_col5, #T_63fee_row10_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_63fee_row0_col4 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_63fee_row0_col5, #T_63fee_row7_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_63fee_row0_col6 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_63fee_row0_col7 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_63fee_row1_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_63fee_row1_col2, #T_63fee_row1_col5 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_63fee_row1_col3, #T_63fee_row2_col3 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_63fee_row1_col4 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_63fee_row1_col6 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_63fee_row1_col7, #T_63fee_row2_col7, #T_63fee_row4_col3 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_63fee_row1_col8, #T_63fee_row8_col10 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_63fee_row1_col9, #T_63fee_row2_col8, #T_63fee_row9_col2 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_63fee_row1_col10 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_63fee_row2_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_63fee_row2_col1 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_63fee_row2_col4, #T_63fee_row9_col0, #T_63fee_row9_col3 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_63fee_row2_col5 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_63fee_row2_col6, #T_63fee_row4_col8 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_63fee_row2_col9, #T_63fee_row3_col5, #T_63fee_row5_col0, #T_63fee_row8_col6 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_63fee_row2_col10 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_63fee_row3_col0, #T_63fee_row3_col6 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_63fee_row3_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_63fee_row3_col2 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_63fee_row3_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_63fee_row3_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_63fee_row3_col8 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_63fee_row3_col9, #T_63fee_row5_col10 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_63fee_row3_col10 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_63fee_row4_col0, #T_63fee_row6_col10 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_63fee_row4_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_63fee_row4_col2, #T_63fee_row8_col1 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_63fee_row4_col5 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_63fee_row4_col6, #T_63fee_row8_col0, #T_63fee_row10_col1 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_63fee_row4_col7 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_63fee_row4_col9 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_63fee_row4_col10 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_63fee_row5_col1 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_63fee_row5_col2 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_63fee_row5_col3 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_63fee_row5_col4, #T_63fee_row6_col4 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_63fee_row5_col6 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_63fee_row5_col7 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_63fee_row5_col8 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_63fee_row5_col9, #T_63fee_row9_col5 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_63fee_row6_col0 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_63fee_row6_col1 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_63fee_row6_col2, #T_63fee_row9_col4 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_63fee_row6_col3, #T_63fee_row7_col4 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_63fee_row6_col5 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_63fee_row6_col7, #T_63fee_row7_col8 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_63fee_row6_col8, #T_63fee_row8_col9 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_63fee_row6_col9 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_63fee_row7_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_63fee_row7_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_63fee_row7_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_63fee_row7_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_63fee_row7_col9 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_63fee_row7_col10 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_63fee_row8_col2, #T_63fee_row9_col1 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_63fee_row8_col3 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_63fee_row8_col4 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_63fee_row8_col5 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_63fee_row8_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_63fee_row9_col6 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_63fee_row9_col7 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_63fee_row9_col8 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_63fee_row9_col10 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_63fee_row10_col2 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_63fee_row10_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_63fee_row10_col6 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_63fee_row10_col8 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_63fee_row10_col9 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_63fee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63fee_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_63fee_level0_col1" class="col_heading level0 col1" >No health insurance coverage</th>
#       <th id="T_63fee_level0_col2" class="col_heading level0 col2" >Unemployed</th>
#       <th id="T_63fee_level0_col3" class="col_heading level0 col3" >No vehicles available</th>
#       <th id="T_63fee_level0_col4" class="col_heading level0 col4" >Child</th>
#       <th id="T_63fee_level0_col5" class="col_heading level0 col5" >Foreign born</th>
#       <th id="T_63fee_level0_col6" class="col_heading level0 col6" >Speak English less than "very well"</th>
#       <th id="T_63fee_level0_col7" class="col_heading level0 col7" >Median age (years)</th>
#       <th id="T_63fee_level0_col8" class="col_heading level0 col8" >Less than $25,000</th>
#       <th id="T_63fee_level0_col9" class="col_heading level0 col9" >Less than 12th grade</th>
#       <th id="T_63fee_level0_col10" class="col_heading level0 col10" >Without a broadband Internet subscription</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63fee_level0_row0" class="row_heading level0 row0" >Year</th>
#       <td id="T_63fee_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_63fee_row0_col1" class="data row0 col1" >-0.274680</td>
#       <td id="T_63fee_row0_col2" class="data row0 col2" >-0.463730</td>
#       <td id="T_63fee_row0_col3" class="data row0 col3" >-0.053434</td>
#       <td id="T_63fee_row0_col4" class="data row0 col4" >-0.002857</td>
#       <td id="T_63fee_row0_col5" class="data row0 col5" >0.013249</td>
#       <td id="T_63fee_row0_col6" class="data row0 col6" >-0.015935</td>
#       <td id="T_63fee_row0_col7" class="data row0 col7" >0.086371</td>
#       <td id="T_63fee_r

# %%
plt.figure(figsize = (12,10))
sns.heatmap(correlation, cmap = 'winter')
plt.title('Heat Map showing Correlations among variables', size = 15)
plt.savefig("heatmap.png")
plt.show()

# %%
plt.figure(figsize = (3600,4320))
sns.pairplot(df2)

# %%
df2.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'No health insurance coverage'}>,
#         <AxesSubplot:title={'center':'Unemployed'}>],
#        [<AxesSubplot:title={'center':'No vehicles available'}>,
#         <AxesSubplot:title={'center':'Child'}>,
#         <AxesSubplot:title={'center':'Foreign born'}>],
#        [<AxesSubplot:title={'center':'Speak English less than "very well"'}>,
#         <AxesSubplot:title={'center':'Median age (years)'}>,
#         <AxesSubplot:title={'center':'Less than $25,000'}>],
#        [<AxesSubplot:title={'center':'Less than 12th grade'}>,
#         <AxesSubplot:title={'center':'Without a broadband Internet subscription'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
mean = np.mean(df2["No health insurance coverage"])
median = np.median(df2["No health insurance coverage"])
std = np.std(df2["No health insurance coverage"])

plt.figure(figsize = (10,8))
plt.hist(df2["No health insurance coverage"], bins=12, edgecolor='black')

plt.title("% of No health Insurance coverage")
plt.xlabel("% of No health Insurance coverage")
plt.ylabel("Frequency")

plt.axvline(x = mean, color="#FD4E40", linestyle = "solid", linewidth=2, label="Mean")
plt.axvline(x = median, color="#90ee90", linestyle="solid", linewidth=2,label="Median")

plt.axvline(x = mean+std, color="#FFB908", linestyle = "solid", linewidth=2, label="Standard Deviation")
plt.axvline(x = mean-std, color="#FFB908", linestyle = "solid", linewidth=2)

plt.axvline(x = mean+std*2, color="#FFB908", linestyle = "solid", linewidth=2)
plt.axvline(x = mean-std*2, color="#FFB908", linestyle = "solid", linewidth=2)

plt.axvline(x = mean+std*3, color="#FFB908", linestyle = "solid", linewidth=2)
plt.axvline(x = mean-std*3, color="#FFB908", linestyle = "solid", linewidth=2)

plt.legend(loc=1)
plt.savefig("% of No health Insurance coverage Distribution.png")
plt.show()

# %%
mean = np.mean(df2["Less than $25,000"])
median = np.median(df2["Less than $25,000"])
std = np.std(df2["Less than $25,000"])

plt.figure(figsize = (10,8))
plt.hist(df2["Less than $25,000"],bins=12, edgecolor='black')

plt.title("% of Less than $25,000 Distribution")
plt.xlabel("% of Less than $25,000")
plt.ylabel("Frequency")

plt.axvline(x = mean, color="#FD4E40", linestyle = "solid", linewidth=2, label="Mean")
plt.axvline(x = median, color="#90ee90", linestyle="solid", linewidth=2,label="Median")

plt.axvline(x = mean+std, color="#FFB908", linestyle = "solid", linewidth=2, label="Standard Deviation")
plt.axvline(x = mean-std, color="#FFB908", linestyle = "solid", linewidth=2)

plt.axvline(x = mean+std*2, color="#FFB908", linestyle = "solid", linewidth=2)
plt.axvline(x = mean-std*2, color="#FFB908", linestyle = "solid", linewidth=2)

plt.axvline(x = mean+std*3, color="#FFB908", linestyle = "solid", linewidth=2)
plt.axvline(x = mean-std*3, color="#FFB908", linestyle = "solid", linewidth=2)

plt.legend(loc=1)
plt.savefig("% of Less than $25,000 Distribution.png")
plt.show()

# %%
w1, w2, w3, w4,w5,w6,w7,w8,w9,w10=correlation['No health insurance coverage'][1:]+correlation['Less than $25,000'][1:]
w8=-w8
print(w1, w2, w3, w4,w5,w6,w7,w8,w9,w10)
# Out:
# 1.448910641487508 1.0755463511989285 0.9645753075470636 0.5919578073471279 1.1652912267227837 1.1074287006595287 -0.07746284690658119 -1.448910641487508 1.0953870006472701 0.33057204745234803

# %%
w1= 0.2
w2= 0.1
w3= 0.01
w4= 0.05
w5= 0.02
w6= 0.1
w7= 0.05
w8= 0.02
w9= 0.4
w10= 0.05

df2['Weighted Mean'] = (df2['No health insurance coverage']*w1 + df2['Unemployed']*w2 + df2['No vehicles available']*w3
                        + df2['Child']*w4 + df1['Foreign born']*w5 +df2['Speak English less than "very well"']*w6 + 
                        df2['Without a broadband Internet subscription']*w7 + df2['Median age (years)']*w8 + 
                        df2['Less than $25,000']*w9 + df1['Less than 12th grade']*w10)/(w1+w2+w3+w4+w5+w6+w7+w8+w9+w10)

# %%
df2.head()
# Out:
#          Municipality  Year  No health insurance coverage  Unemployed  \
# 0     Bloomfield town  2020                          0.13        0.04
# 1  Bloomfield village  2020                          0.07        0.04
# 2     Burlington city  2020                          0.00        0.00
# 3         Darien town  2020                          0.12        0.01
# 4      Darien village  2020                          0.07        0.05
#
#    No vehicles available  Child  Foreign born  \
# 0                   0.01   0.32          0.11
# 1                   0.02   0.39          0.03
# 2                   0.00   0.00          0.00
# 3                   0.02   0.35          0.08
# 4                   0.00   0.31          0.05
#
#    Speak English less than "very well"  Median age (years)  Less than $25,000  \
# 0                                 0.07                34.9               0.23
# 1                                 0.02                35.9               0.19
# 2                                 0.00                 0.0               0.00
# 3                                 0.10                43.7               0.17
# 4                                 0.02                36.7               0.08
#
#    Less than 12th grade  Without a broadband Internet subscription  \
# 0                  0.15                                       0.20
# 1                  0.15                                       0.19
# 2                  0.00                                       1.00
# 3                  0.15                                       0.15
# 4                  0.07                                       0.15
#
#    Weighted Mean
# 0         0.8628
# 1         0.8513
# 2         0.0500
# 3         1.0113
# 4         0.8145

# %%
df3 = df2.sort_values(['Year','Weighted Mean'], ascending = (False, False))

# %%
df3[df3['Year']==2020].head(3)
# Out:
#                       Municipality  Year  No health insurance coverage  \
# 10  Fontana-on-Geneva Lake village  2020                          0.05
# 20                     Sharon town  2020                          0.02
# 6                     Delavan town  2020                          0.05
#
#     Unemployed  No vehicles available  Child  Foreign born  \
# 10        0.01                   0.04   0.18          0.08
# 20        0.02                   0.03   0.24          0.05
# 6         0.02                   0.06   0.26          0.04
#
#     Speak English less than "very well"  Median age (years)  \
# 10                                 0.02                58.0
# 20                                 0.03                53.8
# 6                                  0.02                50.7
#
#     Less than $25,000  Less than 12th grade  \
# 10               0.11                  0.04
# 20               0.12                  0.08
# 6                0.14                  0.11
#
#     Without a broadband Internet subscription  Weighted Mean
# 10                                       0.05         1.2325
# 20                                       0.22         1.1613
# 6                                        0.19         1.1134

# %%
df3[df3['Year']==2019].head(3)
# Out:
#                       Municipality  Year  No health insurance coverage  \
# 40  Fontana-on-Geneva Lake village  2019                          0.03
# 50                     Sharon town  2019                          0.03
# 36                    Delavan town  2019                          0.06
#
#     Unemployed  No vehicles available  Child  Foreign born  \
# 40        0.02                   0.04   0.18          0.05
# 50        0.01                   0.03   0.23          0.08
# 36        0.02                   0.06   0.24          0.05
#
#     Speak English less than "very well"  Median age (years)  \
# 40                                 0.01                59.2
# 50                                 0.05                53.6
# 36                                 0.04                50.1
#
#     Less than $25,000  Less than 12th grade  \
# 40               0.11                  0.04
# 50               0.12                  0.10
# 36               0.15                  0.12
#
#     Without a broadband Internet subscription  Weighted Mean
# 40                                       0.09         1.2539
# 50                                       0.24         1.1624
# 36                                       0.21         1.1101

# %%
df3[df3['Year']==2018].head(3)
# Out:
#                       Municipality  Year  No health insurance coverage  \
# 70  Fontana-on-Geneva Lake village  2018                          0.04
# 80                     Sharon town  2018                          0.05
# 84                       Troy town  2018                          0.05
#
#     Unemployed  No vehicles available  Child  Foreign born  \
# 70        0.01                   0.04   0.17          0.04
# 80        0.01                   0.04   0.20          0.07
# 84        0.03                   0.02   0.21          0.02
#
#     Speak English less than "very well"  Median age (years)  \
# 70                                 0.01                59.2
# 80                                 0.05                53.8
# 84                                 0.01                51.7
#
#     Less than $25,000  Less than 12th grade  \
# 70               0.10                  0.03
# 80               0.13                  0.10
# 84               0.16                  0.05
#
#     Without a broadband Internet subscription  Weighted Mean
# 70                                       0.10         1.2502
# 80                                       0.30         1.1758
# 84                                       0.16         1.1336

# %%
df3[df3['Year']==2017].head(3)
# Out:
#                        Municipality  Year  No health insurance coverage  \
# 100  Fontana-on-Geneva Lake village  2017                          0.04
# 114                       Troy town  2017                          0.05
# 110                     Sharon town  2017                          0.06
#
#      Unemployed  No vehicles available  Child  Foreign born  \
# 100        0.01                   0.03   0.19          0.03
# 114        0.02                   0.01   0.22          0.02
# 110        0.01                   0.03   0.22          0.06
#
#      Speak English less than "very well"  Median age (years)  \
# 100                                 0.01                58.5
# 114                                 0.01                51.6
# 110                                 0.03                51.9
#
#      Less than $25,000  Less than 12th grade  \
# 100               0.11                  0.04
# 114               0.17                  0.06
# 110               0.12                  0.09
#
#      Without a broadband Internet subscription  Weighted Mean
# 100                                       0.11         1.2419
# 114                                       0.17         1.1360
# 110                                       0.30         1.1340

# %%
df3[df3['Year']==2016].head(3)
# Out:
#                        Municipality  Year  No health insurance coverage  \
# 130  Fontana-on-Geneva Lake village  2016                          0.03
# 140                     Sharon town  2016                          0.06
# 127                  East Troy town  2016                          0.04
#
#      Unemployed  No vehicles available  Child  Foreign born  \
# 130        0.02                   0.03   0.23          0.01
# 140        0.02                   0.04   0.22          0.05
# 127        0.02                   0.00   0.24          0.02
#
#      Speak English less than "very well"  Median age (years)  \
# 130                                 0.01                56.9
# 140                                 0.03                52.3
# 127                                 0.01                52.0
#
#      Less than $25,000  Less than 12th grade  \
# 130               0.11                  0.03
# 140               0.13                  0.10
# 127               0.14                  0.05
#
#      Without a broadband Internet subscription  Weighted Mean
# 130                                        1.0         1.2545
# 140                                        1.0         1.1824
# 127                                        1.0         1.1719

# %%
df3[df3['Year']==2015].head(3)
# Out:
#                        Municipality  Year  No health insurance coverage  \
# 160  Fontana-on-Geneva Lake village  2015                          0.03
# 157                  East Troy town  2015                          0.06
# 170                     Sharon town  2015                          0.07
#
#      Unemployed  No vehicles available  Child  Foreign born  \
# 160        0.01                   0.04   0.22          0.02
# 157        0.03                   0.00   0.22          0.01
# 170        0.02                   0.04   0.22          0.05
#
#      Speak English less than "very well"  Median age (years)  \
# 160                                 0.01                58.7
# 157                                 0.00                52.1
# 170                                 0.03                51.8
#
#      Less than $25,000  Less than 12th grade  \
# 160               0.10                  0.02
# 157               0.18                  0.07
# 170               0.16                  0.09
#
#      Without a broadband Internet subscription  Weighted Mean
# 160                                        1.0         1.2848
# 157                                        1.0         1.1937
# 170                                        1.0         1.1859

# %%
df3[df3['Year']==2014].head(3)
# Out:
#                        Municipality  Year  No health insurance coverage  \
# 190  Fontana-on-Geneva Lake village  2014                          0.03
# 196                       Linn town  2014                          0.08
# 200                     Sharon town  2014                          0.09
#
#      Unemployed  No vehicles available  Child  Foreign born  \
# 190        0.01                   0.05   0.19          0.02
# 196        0.07                   0.03   0.24          0.07
# 200        0.03                   0.02   0.24          0.04
#
#      Speak English less than "very well"  Median age (years)  \
# 190                                 0.01                58.5
# 196                                 0.02                51.7
# 200                                 0.02                50.1
#
#      Less than $25,000  Less than 12th grade  \
# 190               0.12                  0.03
# 196               0.19                  0.08
# 200               0.13                  0.07
#
#      Without a broadband Internet subscription  Weighted Mean
# 190                                        1.0         1.2879
# 196                                        1.0         1.2027
# 200                                        1.0         1.1435

# %%
from sklearn.preprocessing import StandardScaler
df2[df2.columns[2:]]=StandardScaler().fit_transform(df2[df2.columns[2:]])

# %%
w1= 0.2
w2= 0.1
w3= 0.01
w4= 0.05
w5= 0.02
w6= 0.1
w7= 0.05
w8= 0.02
w9= 0.4
w10= 0.05

df2['Weighted Mean'] = (df2['No health insurance coverage']*w1 + df2['Unemployed']*w2 + df2['No vehicles available']*w3
                        + df2['Child']*w4 + df1['Foreign born']*w5 +df2['Speak English less than "very well"']*w6 + 
                        df2['Without a broadband Internet subscription']*w7 + df2['Median age (years)']*w8 + 
                        df2['Less than $25,000']*w9 + df1['Less than 12th grade']*w10)/(w1+w2+w3+w4+w5+w6+w7+w8+w9+w10)

# %%
df3 = df2.sort_values(['Year','Weighted Mean'], ascending = (False, False))

# %%
df3[df3['Year']==2020].head(3)
# Out:
#        Municipality  Year  No health insurance coverage  Unemployed  \
# 0   Bloomfield town  2020                      1.400694    0.271914
# 27  Whitewater city  2020                     -0.062718   -0.170737
# 5      Delavan city  2020                      0.912890   -0.170737
#
#     No vehicles available     Child  Foreign born  \
# 0               -0.856618  0.692008      1.434535
# 27               0.896694 -1.174510     -0.083109
# 5                1.247357 -0.241251      1.181594
#
#     Speak English less than "very well"  Median age (years)  \
# 0                              0.972037           -0.555599
# 27                            -0.422278           -1.711337
# 5                              1.529763           -0.304741
#
#     Less than $25,000  Less than 12th grade  \
# 0            0.939467              1.333004
# 27           2.246010             -0.478195
# 5            0.820690              1.333004
#
#     Without a broadband Internet subscription  Weighted Mean
# 0                                   -0.815234       0.764181
# 27                                  -0.743261       0.709411
# 5                                   -1.007161       0.600215

# %%
df3[df3['Year']==2019].head(3)
# Out:
#        Municipality  Year  No health insurance coverage  Unemployed  \
# 57  Whitewater city  2019                     -0.062718    0.271914
# 35     Delavan city  2019                      1.156792   -0.170737
# 51   Sharon village  2019                      0.425086    0.714565
#
#     No vehicles available     Child  Foreign born  \
# 57               1.948682 -1.574478     -0.336050
# 35               3.000669  0.158718      1.940416
# 51              -0.155293  0.558686      1.181594
#
#     Speak English less than "very well"  Median age (years)  \
# 57                            -0.422278           -1.720297
# 35                             2.366352           -0.448089
# 51                             1.529763           -0.367456
#
#     Less than $25,000  Less than 12th grade  \
# 57            2.60234             -0.276950
# 35            0.82069              2.137981
# 51            0.82069              3.345446
#
#     Without a broadband Internet subscription  Weighted Mean
# 57                                  -0.719270       0.888050
# 35                                  -0.839225       0.778316
# 51                                  -1.007161       0.620900

# %%
df3[df3['Year']==2018].head(3)
# Out:
#         Municipality  Year  No health insurance coverage  Unemployed  \
# 87   Whitewater city  2018                      0.668988    0.271914
# 65      Delavan city  2018                      2.132400   -0.170737
# 86  Walworth village  2018                      0.912890   -0.613388
#
#     No vehicles available    Child  Foreign born  \
# 87               2.299344 -1.17451      0.169832
# 65               2.650007  0.29204      2.699238
# 86               0.546032  0.29204      2.193357
#
#     Speak English less than "very well"  Median age (years)  \
# 87                             0.135448           -1.711337
# 65                             2.924078           -0.448089
# 86                             1.529763           -0.215149
#
#     Less than $25,000  Less than 12th grade  \
# 87           2.839894             -0.075706
# 65           0.820690              2.540469
# 86           1.177020              0.729271
#
#     Without a broadband Internet subscription  Weighted Mean
# 87                                  -0.719270       1.209769
# 65                                  -0.743261       1.038767
# 86                                  -0.599316       0.739617

# %%
df3[df3['Year']==2017].head(3)
# Out:
#          Municipality  Year  No health insurance coverage  Unemployed  \
# 117   Whitewater city  2017                      0.668988    1.157216
# 95       Delavan city  2017                      2.376302    0.271914
# 116  Walworth village  2017                      0.912890    0.714565
#
#      No vehicles available     Child  Foreign born  \
# 117               2.650007 -1.174510     -0.083109
# 95                2.650007  0.292040      2.699238
# 116               0.896694  0.158718      2.699238
#
#      Speak English less than "very well"  Median age (years)  \
# 117                            -0.143415           -1.711337
# 95                              3.202942           -0.394333
# 116                             1.808626           -0.582477
#
#      Less than $25,000  Less than 12th grade  \
# 117           3.077447              0.125538
# 95            0.939467              2.540469
# 116           1.414574              0.729271
#
#      Without a broadband Internet subscription  Weighted Mean
# 117                                  -0.671288       1.371640
# 95                                   -0.695279       1.210684
# 116                                  -0.479361       0.991212

# %%
df3[df3['Year']==2016].head(3)
# Out:
#          Municipality  Year  No health insurance coverage  Unemployed  \
# 147   Whitewater city  2016                      0.668988    1.157216
# 125      Delavan city  2016                      2.132400    0.714565
# 146  Walworth village  2016                      0.912890    1.157216
#
#      No vehicles available     Child  Foreign born  \
# 147               2.650007 -0.907864     -0.083109
# 125               2.299344  0.425363      2.446297
# 146               0.896694  0.292040      2.699238
#
#      Speak English less than "very well"  Median age (years)  \
# 147                             0.135448           -1.711337
# 125                             2.924078           -0.528721
# 146                             2.087489           -0.537681
#
#      Less than $25,000  Less than 12th grade  \
# 147           3.433777              0.125538
# 125           1.414574              2.540469
# 146           1.652127              0.528027
#
#      Without a broadband Internet subscription  Weighted Mean
# 147                                   1.104038       1.644157
# 125                                   1.104038       1.458563
# 146                                   1.104038       1.244617

# %%
df3[df3['Year']==2015].head(3)
# Out:
#         Municipality  Year  No health insurance coverage  Unemployed  \
# 177  Whitewater city  2015                      0.668988    0.714565
# 155     Delavan city  2015                      2.376302    1.599867
# 171   Sharon village  2015                      1.156792    2.485169
#
#      No vehicles available     Child  Foreign born  \
# 177               2.650007 -0.907864     -0.083109
# 155               2.650007  0.425363      2.446297
# 171               0.546032  0.692008      0.169832
#
#      Speak English less than "very well"  Median age (years)  \
# 177                             0.135448           -1.711337
# 155                             2.645215           -0.555599
# 171                             0.135448           -0.430170
#
#      Less than $25,000  Less than 12th grade  \
# 177           3.790107              0.125538
# 155           1.295797              2.540469
# 171           1.889680              1.131759
#
#      Without a broadband Internet subscription  Weighted Mean
# 177                                   1.104038       1.742424
# 155                                   1.104038       1.523446
# 171                                   1.104038       1.344151

# %%
df3[df3['Year']==2014].head(3)
# Out:
#          Municipality  Year  No health insurance coverage  Unemployed  \
# 207   Whitewater city  2014                      0.912890    0.714565
# 184    Darien village  2014                      2.864106    3.813122
# 195  Lake Geneva city  2014                      2.132400    1.157216
#
#      No vehicles available     Child  Foreign born  \
# 207               2.650007 -0.507896      0.422772
# 184              -1.207281  0.425363      1.181594
# 195               1.948682  0.158718      1.687475
#
#      Speak English less than "very well"  Median age (years)  \
# 207                             0.414311           -1.675501
# 184                             1.808626           -0.636232
# 195                             1.529763           -0.027006
#
#      Less than $25,000  Less than 12th grade  \
# 207           3.552554              0.528027
# 184           1.295797              1.131759
# 195           1.177020              1.131759
#
#      Without a broadband Internet subscription  Weighted Mean
# 207                                   1.104038       1.746184
# 184                                   1.104038       1.713987
# 195                                   1.104038       1.257470

# %%
df3.to_csv('walwortwheightedmean.csv', index = False)

# %%
df_temp=df3[['Municipality','Year','Weighted Mean']]

# %%
mapp={}
for place in df_temp['Municipality'].unique():
    mapp[place]=df_temp[df_temp['Municipality']==place]

# %%
mapp['Bloomfield town']
# Out:
#         Municipality  Year  Weighted Mean
# 0    Bloomfield town  2020       0.764181
# 30   Bloomfield town  2019       0.455744
# 60   Bloomfield town  2018       0.377060
# 90   Bloomfield town  2017       0.341210
# 120  Bloomfield town  2016       0.565975
# 150  Bloomfield town  2015       0.143461
# 180  Bloomfield town  2014       0.449401

# %%
def ad_test(dataset):
     dftest = adfuller(dataset, autolag = 'AIC')
     print('ADF : ',dftest[0])
     print('P-Value : ', dftest[1])
     print('Num Of Lags : ', dftest[2])
     print('Num Of Observations Used For ADF Regression:', dftest[3])
     print('Critical Values :')
     for key, val in dftest[4].items():
         print('\t',key, ': ', val)

# %%
for place in mapp:
    print(place)
    ad_test(mapp[place]['Weighted Mean'])
    print('----')
    if dftest[1]>0.05:
            mapp['Weighted Mean'].diff().dropna()
# Out:
# Bloomfield town
# ADF :  -3.6527322766251276
# P-Value :  0.004829336066250606
# Num Of Lags :  0
# Num Of Observations Used For ADF Regression: 6
# Critical Values :
# 	 1% :  -5.354256481481482
# 	 5% :  -3.6462381481481483
# 	 10% :  -2.901197777777778
# ----
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
#       3 ad_test(mapp[place]['Weighted Mean'])
#       4 print('----')
# ----> 5 if dftest[1]>0.05:
#       6         mapp['Weighted Mean'].diff().dropna()
#
# NameError: name 'dftest' is not defined

# %%
# missing value error
# should consider imputing 
# prolly mean 
train_data, test_data = df_diff[0:int(len(df)*0.7)], df[int(len(df)*0.7):]
model_autoARIMA = auto_arima(train_data, test='adf', seasonal=True, trace=True,error_action='ignore',suppress_warnings=True, stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=210.428, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=211.758, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=211.084, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=208.474, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.11 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0]
# Total fit time: 0.351 seconds

# %%
#recreate the ARIMA model after each new observation as we have limited number of obs
#will most likely overfit 
train_data, test_data = df[0:int(len(df)*0.7)], df[int(len(df)*0.7):]
training_data = train_data['Weighted Mean'].values
test_data = test_data['Weighted Mean'].values
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = sm.tsa.arima.ARIMA(history, order=(0,0,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mean_squared_error(test_data, model_predictions)
print('Mean Squared Error {}'.format(MSE_error))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\envs\dsda\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\miniconda3\envs\dsda\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\miniconda3\envs\dsda\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Weighted Mean'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [49], in <cell line: 4>()
#       1 #recreate the ARIMA model after each new observation as we have limited number of obs
#       2 #will most likely overfit
#       3 train_data, test_data = df[0:int(len(df)*0.7)], df[int(len(df)*0.7):]
# ----> 4 training_data = train_data['Weighted Mean'].values
#       5 test_data = test_data['Weighted Mean'].values
#       6 history = [x for x in training_data]
#
# File ~\miniconda3\envs\dsda\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\miniconda3\envs\dsda\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Weighted Mean'

# %%
# viz to track performance
test_set_range = df[int(len(df)*0.7):].index
plt.plot(test_set_range, model_predictions, color='blue', marker='o', linestyle='dashed',label='Predicted Value')
plt.plot(test_set_range, test_data, color='red', label='Actual Value')
plt.title('Prediction')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.legend()
plt.show()
